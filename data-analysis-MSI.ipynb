# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\ellah\OneDrive\Data Science Projects\overdose-data-us\VSRR_Provisional_Drug_Overdose_Death_Counts.csv')

# %%
df.head()
# Out:
#   State  Year     Month           Period        Indicator Data Value  \
# 0    AK  2015   January  12 month-ending  Cocaine (T40.5)        NaN
# 1    AK  2015  February  12 month-ending  Cocaine (T40.5)        NaN
# 2    AK  2015     March  12 month-ending  Cocaine (T40.5)        NaN
# 3    AK  2015     April  12 month-ending  Cocaine (T40.5)        NaN
# 4    AK  2015       May  12 month-ending  Cocaine (T40.5)        NaN
#
#    Percent Complete  Percent Pending Investigation State Name  \
# 0               100                            0.0     Alaska
# 1               100                            0.0     Alaska
# 2               100                            0.0     Alaska
# 3               100                            0.0     Alaska
# 4               100                            0.0     Alaska
#
#                                             Footnote Footnote Symbol  \
# 0  Numbers may differ from published reports usin...              **
# 1  Numbers may differ from published reports usin...              **
# 2  Numbers may differ from published reports usin...              **
# 3  Numbers may differ from published reports usin...              **
# 4  Numbers may differ from published reports usin...              **
#
#   Predicted Value
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN

# %%
df["State"].nunique()
# Out:
# 54

# %%
df.shape
# Out:
# (78120, 12)

# %%
df.columns
# Out:
# Index(['State', 'Year', 'Month', 'Period', 'Indicator', 'Data Value',
#        'Percent Complete', 'Percent Pending Investigation', 'State Name',
#        'Footnote', 'Footnote Symbol', 'Predicted Value'],
#       dtype='object')

# %%
df['Indicator'].value_counts()
# Out:
# Indicator
# Number of Deaths                                                               6696
# Percent with drugs specified                                                   6696
# Number of Drug Overdose Deaths                                                 6696
# Cocaine (T40.5)                                                                6448
# Natural & semi-synthetic opioids (T40.2)                                       6448
# Methadone (T40.3)                                                              6448
# Heroin (T40.1)                                                                 6448
# Natural, semi-synthetic, & synthetic opioids, incl. methadone (T40.2-T40.4)    6448
# Natural & semi-synthetic opioids, incl. methadone (T40.2, T40.3)               6448
# Opioids (T40.0-T40.4,T40.6)                                                    6448
# Psychostimulants with abuse potential (T43.6)                                  6448
# Synthetic opioids, excl. methadone (T40.4)                                     6448
# Name: count, dtype: int64

# %%
df = df[~df['Indicator'].isin(['Number of Deaths', 'Percent with drugs specified', 'Number of Drug Overdose Deaths'])]

# %%
df.shape
# Out:
# (58032, 12)

# %%
df['Indicator'] = df['Indicator'].replace({
    'Methadone (T40.3)':'Methadone',
    'Natural, semi-synthetic, & synthetic opioids, incl. methadone (T40.2-T40.4)':'Methadone',
    'Natural & semi-synthetic opioids, incl. methadone (T40.2, T40.3)':'Methadone'
})

df['Indicator'] = df['Indicator'].replace({
    'Natural & semi-synthetic opioids (T40.2)':'Opioids',
    'Opioids (T40.0-T40.4,T40.6)':'Opioids',
    'Synthetic opioids, excl. methadone (T40.4)':'Opioids'
})

df['Indicator'] = df['Indicator'].replace({
    'Cocaine (T40.5)':'Cocaine',
    'Heroin (T40.1)':'Heroin',
    'Psychostimulants with abuse potential (T43.6)':'Psychostimulants'
})

# %%
df['Indicator'].value_counts()
# Out:
# Indicator
# Methadone           19344
# Opioids             19344
# Cocaine              6448
# Heroin               6448
# Psychostimulants     6448
# Name: count, dtype: int64

# %%
df.isna().sum()
# Out:
# State                                0
# Year                                 0
# Month                                0
# Period                               0
# Indicator                            0
# Data Value                       14293
# Percent Complete                     0
# Percent Pending Investigation        0
# State Name                           0
# Footnote                             0
# Footnote Symbol                      0
# Predicted Value                  14242
# dtype: int64

# %%
df['Data Value'].value_counts()
# Out:
# Data Value
# 32       240
# 27       238
# 28       236
# 29       223
# 31       220
#         ...
# 2,544      1
# 2,686      1
# 2,685      1
# 2,755      1
# 2,719      1
# Name: count, Length: 4567, dtype: int64

# %%
df.drop(['Data Value', 'Predicted Value'], axis=1, inplace=True)

# %%
df.head()
# Out:
#   State  Year     Month           Period Indicator  Percent Complete  \
# 0    AK  2015   January  12 month-ending   Cocaine               100
# 1    AK  2015  February  12 month-ending   Cocaine               100
# 2    AK  2015     March  12 month-ending   Cocaine               100
# 3    AK  2015     April  12 month-ending   Cocaine               100
# 4    AK  2015       May  12 month-ending   Cocaine               100
#
#    Percent Pending Investigation State Name  \
# 0                            0.0     Alaska
# 1                            0.0     Alaska
# 2                            0.0     Alaska
# 3                            0.0     Alaska
# 4                            0.0     Alaska
#
#                                             Footnote Footnote Symbol
# 0  Numbers may differ from published reports usin...              **
# 1  Numbers may differ from published reports usin...              **
# 2  Numbers may differ from published reports usin...              **
# 3  Numbers may differ from published reports usin...              **
# 4  Numbers may differ from published reports usin...              **

# %%
df['Percent Pending Investigation'].value_counts()
# Out:
# Percent Pending Investigation
# 0.000000    7443
# 0.020793      18
# 0.008805      18
# 0.008415      18
# 0.035356      18
#             ...
# 0.285906       9
# 0.421300       9
# 0.590863       9
# 0.794795       9
# 0.069946       9
# Name: count, Length: 5591, dtype: int64

# %%
df['Percent Complete'].value_counts()
# Out:
# Percent Complete
# 100    58032
# Name: count, dtype: int64

# %%
df.drop(['Percent Complete'], axis=1, inplace=True)

# %%
df.head()
# Out:
#   State  Year     Month           Period Indicator  \
# 0    AK  2015   January  12 month-ending   Cocaine
# 1    AK  2015  February  12 month-ending   Cocaine
# 2    AK  2015     March  12 month-ending   Cocaine
# 3    AK  2015     April  12 month-ending   Cocaine
# 4    AK  2015       May  12 month-ending   Cocaine
#
#    Percent Pending Investigation State Name  \
# 0                            0.0     Alaska
# 1                            0.0     Alaska
# 2                            0.0     Alaska
# 3                            0.0     Alaska
# 4                            0.0     Alaska
#
#                                             Footnote Footnote Symbol
# 0  Numbers may differ from published reports usin...              **
# 1  Numbers may differ from published reports usin...              **
# 2  Numbers may differ from published reports usin...              **
# 3  Numbers may differ from published reports usin...              **
# 4  Numbers may differ from published reports usin...              **

# %%
df['Footnote Symbol'].value_counts()
# Out:
# Footnote Symbol
# **    50544
# *      7488
# Name: count, dtype: int64

# %%
df.drop(['Footnote Symbol'], axis=1, inplace=True)

# %%
df.head()
# Out:
#   State  Year     Month           Period Indicator  \
# 0    AK  2015   January  12 month-ending   Cocaine
# 1    AK  2015  February  12 month-ending   Cocaine
# 2    AK  2015     March  12 month-ending   Cocaine
# 3    AK  2015     April  12 month-ending   Cocaine
# 4    AK  2015       May  12 month-ending   Cocaine
#
#    Percent Pending Investigation State Name  \
# 0                            0.0     Alaska
# 1                            0.0     Alaska
# 2                            0.0     Alaska
# 3                            0.0     Alaska
# 4                            0.0     Alaska
#
#                                             Footnote
# 0  Numbers may differ from published reports usin...
# 1  Numbers may differ from published reports usin...
# 2  Numbers may differ from published reports usin...
# 3  Numbers may differ from published reports usin...
# 4  Numbers may differ from published reports usin...

# %%
df['Period'].value_counts()
# Out:
# Period
# 12 month-ending    58032
# Name: count, dtype: int64

# %%
df.drop(['Period'], axis=1, inplace=True)

# %%
df.head()
# Out:
#   State  Year     Month Indicator  Percent Pending Investigation State Name  \
# 0    AK  2015   January   Cocaine                            0.0     Alaska
# 1    AK  2015  February   Cocaine                            0.0     Alaska
# 2    AK  2015     March   Cocaine                            0.0     Alaska
# 3    AK  2015     April   Cocaine                            0.0     Alaska
# 4    AK  2015       May   Cocaine                            0.0     Alaska
#
#                                             Footnote
# 0  Numbers may differ from published reports usin...
# 1  Numbers may differ from published reports usin...
# 2  Numbers may differ from published reports usin...
# 3  Numbers may differ from published reports usin...
# 4  Numbers may differ from published reports usin...
